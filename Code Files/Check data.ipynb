# %%
import pandas as pd

# %%
df = pd.read_csv("Merged data draft 3 rows 10 to 60.csv")
df
# Out:
#     Unnamed: 0  Sample Number Lubrication Condition Pin Material  Weight (kg)  \
# 0            0              1        No Lubrication        Brass            8
# 1            1              2        No Lubrication        Brass            8
# 2            2              3        No Lubrication        Brass            8
# 3            3              4        No Lubrication        Brass            8
# 4            4              5        No Lubrication        Brass            9
# ..         ...            ...                   ...          ...          ...
# 91          91             92      Full Lubrication    Aluminium            4
# 92          92             93      Full Lubrication    Aluminium            5
# 93          93             94      Full Lubrication    Aluminium            5
# 94          94             95      Full Lubrication    Aluminium            5
# 95          95             96      Full Lubrication    Aluminium            5
#
# ...

# %%
i = 20
di = pd.read_csv(f"Data/Piezo_{i}.dwf", sep=";", names=["timestamp", "wear", "friction", "const", "ignore"])
di
# Out:
#      timestamp    wear  friction   const  ignore
# 0        0.985  110.14      5.35  102.54     NaN
# 1        1.969  111.16      5.50  102.54     NaN
# 2        2.938  111.98      5.48  102.54     NaN
# 3        3.922  112.67      5.54  102.54     NaN
# 4        4.907  113.61      5.56  102.54     NaN
# ..         ...     ...       ...     ...     ...
# 100     99.000  124.62      6.16  102.54     NaN
# 101     99.985  124.62      6.22  102.54     NaN
# 102    100.969  125.53      6.06  102.54     NaN
# 103    101.954  125.33      6.27  102.54     NaN
# 104    102.938  126.16      6.15  102.54     NaN
#
# [105 rows x 5 columns]

# %%
di["wear"].loc[10:60].mean(), di["friction"].loc[10:60].mean()
# Out:
# (116.53156862745098, 5.807647058823529)

# %%
df.loc[i - 1]
# Out:
# Unnamed: 0                           19
# Sample Number                        20
# Lubrication Condition    No Lubrication
# Pin Material                  Aluminium
# Weight (kg)                           2
# RPM                                 250
# Sensor                            Piezo
# Name of file                   Piezo_20
# wear                         116.531569
# friction                       5.807647
# Name: 19, dtype: object
